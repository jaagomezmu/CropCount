# %%
! pip install pillow
! pip freeze > requirements.txt
# Out:
# Requirement already satisfied: pillow in ./.venv/lib64/python3.12/site-packages (11.0.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from pathlib import Path
from typing import List, Tuple

from PIL import Image

# %%
raw_data_path = Path("data/raw")

# %%
def crop_images(image_paths: List[Path], 
                output_dir: Path, 
                crop_size: Tuple[int, int] = (640, 640), 
                overlap: int = 320) -> None:
    """Crops all images in the provided list of paths into smaller 640x640 tiles and saves them.
    
    Args:
        image_paths (List[Path]): List of paths to the images.
        output_dir (Path): Directory where the cropped images will be saved.
        crop_size (Tuple[int, int], optional): The target size for cropping (width, height). 
                                               Defaults to (640, 640).
        overlap (int, optional): Overlap size between crops to achieve additional tiles. Defaults to 320.
    """
    output_dir.mkdir(parents=True, exist_ok=True)
    
    crop_width, crop_height = crop_size
    for img_path in image_paths:
        with Image.open(img_path) as img:
            img_width, img_height = img.size
            crop_count = 0
            step_x = crop_width - overlap
            step_y = crop_height - overlap
            for top in range(0, img_height - crop_height + 1, step_y):
                for left in range(0, img_width - crop_width + 1, step_x):
                    right = left + crop_width
                    bottom = top + crop_height
                    cropped_img = img.crop((left, top, right, bottom))
                    crop_count += 1
                    save_path = output_dir / f"{img_path.stem}_crop_{crop_count}.jpg"
                    cropped_img.save(save_path)
                    print(f"Cropped and saved image: {save_path}")
            
            print(f"Total crops for {img_path.name}: {crop_count}")

# %%
image_paths = list(raw_data_path.glob('*.JPG'))
output_directory = Path("data/cropped_images")
crop_images(image_paths, output_directory)
# Out:
# Cropped and saved image: data/cropped_images/31_crop_1.jpg
# Cropped and saved image: data/cropped_images/31_crop_2.jpg
# Cropped and saved image: data/cropped_images/31_crop_3.jpg
# Cropped and saved image: data/cropped_images/31_crop_4.jpg
# Cropped and saved image: data/cropped_images/31_crop_5.jpg
# Cropped and saved image: data/cropped_images/31_crop_6.jpg
# Cropped and saved image: data/cropped_images/31_crop_7.jpg
# Cropped and saved image: data/cropped_images/31_crop_8.jpg
# Cropped and saved image: data/cropped_images/31_crop_9.jpg
# Cropped and saved image: data/cropped_images/31_crop_10.jpg
# Cropped and saved image: data/cropped_images/31_crop_11.jpg
# Cropped and saved image: data/cropped_images/31_crop_12.jpg
# Cropped and saved image: data/cropped_images/31_crop_13.jpg
# Cropped and saved image: data/cropped_images/31_crop_14.jpg
# Cropped and saved image: data/cropped_images/31_crop_15.jpg
# Cropped and saved image: data/cropped_images/31_crop_16.jpg
# Cropped and saved image: data/cropped_images/31_crop_17.jpg
# Cropped and saved image: data/cropped_images/31_crop_18.jpg
# Cropped and saved image: data/cropped_images/31_crop_19.jpg
# Cropped and saved image: data/cropped_images/31_crop_20.jpg
# Cropped and saved image: data/cropped_images/31_crop_21.jpg
# Cropped and saved image: data/cropped_images/31_crop_22.jpg
# Cropped and saved image: data/cropped_images/31_crop_23.jpg
# Cropped and saved image: data/cropped_images/31_crop_24.jpg
# Cropped and saved image: data/cropped_images/31_crop_25.jpg
# Cropped and saved image: data/cropped_images/31_crop_26.jpg
# Cropped and saved image: data/cropped_images/31_crop_27.jpg
# Cropped and saved image: data/cropped_images/31_crop_28.jpg
# Cropped and saved image: data/cropped_images/31_crop_29.jpg
# Cropped and saved image: data/cropped_images/31_crop_30.jpg
# Cropped and saved image: data/cropped_images/31_crop_31.jpg
# Cropped and saved image: data/cropped_images/31_crop_32.jpg
# Cropped and saved image: data/cropped_images/31_crop_33.jpg
# Cropped and saved image: data/cropped_images/31_crop_34.jpg
# Cropped and saved image: data/cropped_images/31_crop_35.jpg
# Cropped and saved image: data/cropped_images/31_crop_36.jpg
# Cropped and saved image: data/cropped_images/31_crop_37.jpg
# Cropped and saved image: data/cropped_images/31_crop_38.jpg
# Cropped and saved image: data/cropped_images/31_crop_39.jpg
# Cropped and saved image: data/cropped_images/31_crop_40.jpg
# Cropped and saved image: data/cropped_images/31_crop_41.jpg
# Cropped and saved image: data/cropped_images/31_crop_42.jpg
# Cropped and saved image: data/cropped_images/31_crop_43.jpg
# Cropped and saved image: data/cropped_images/31_crop_44.jpg
# Cropped and saved image: data/cropped_images/31_crop_45.jpg
# Cropped and saved image: data/cropped_images/31_crop_46.jpg
# Cropped and saved image: data/cropped_images/31_crop_47.jpg
# Cropped and saved image: data/cropped_images/31_crop_48.jpg
# Cropped and saved image: data/cropped_images/31_crop_49.jpg
# Cropped and saved image: data/cropped_images/31_crop_50.jpg
# Cropped and saved image: data/cropped_images/31_crop_51.jpg
# Cropped and saved image: data/cropped_images/31_crop_52.jpg
# Cropped and saved image: data/cropped_images/31_crop_53.jpg
# Cropped and saved image: data/cropped_images/31_crop_54.jpg
# Cropped and saved image: data/cropped_images/31_crop_55.jpg
# Cropped and saved image: data/cropped_images/31_crop_56.jpg
# Cropped and saved image: data/cropped_images/31_crop_57.jpg
# Cropped and saved image: data/cropped_images/31_crop_58.jpg
# Cropped and saved image: data/cropped_images/31_crop_59.jpg
# Cropped and saved image: data/cropped_images/31_crop_60.jpg
# Cropped and saved image: data/cropped_images/31_crop_61.jpg
# Cropped and saved image: data/cropped_images/31_crop_62.jpg
# Cropped and saved image: data/cropped_images/31_crop_63.jpg
# Cropped and saved image: data/cropped_images/31_crop_64.jpg
# Cropped and saved image: data/cropped_images/31_crop_65.jpg
# Cropped and saved image: data/cropped_images/31_crop_66.jpg
# Cropped and saved image: data/cropped_images/31_crop_67.jpg
# Cropped and saved image: data/cropped_images/31_crop_68.jpg
# Cropped and saved image: data/cropped_images/31_crop_69.jpg
# Cropped and saved image: data/cropped_images/31_crop_70.jpg
# Cropped and saved image: data/cropped_images/31_crop_71.jpg
# Cropped and saved image: data/cropped_images/31_crop_72.jpg
# Cropped and saved image: data/cropped_images/31_crop_73.jpg
# Cropped and saved image: data/cropped_images/31_crop_74.jpg
# Cropped and saved image: data/cropped_images/31_crop_75.jpg
# Cropped and saved image: data/cropped_images/31_crop_76.jpg
# Cropped and saved image: data/cropped_images/31_crop_77.jpg
# Cropped and saved image: data/cropped_images/31_crop_78.jpg
# Cropped and saved image: data/cropped_images/31_crop_79.jpg
# Cropped and saved image: data/cropped_images/31_crop_80.jpg
# Cropped and saved image: data/cropped_images/31_crop_81.jpg
# Cropped and saved image: data/cropped_images/31_crop_82.jpg
# Cropped and saved image: data/cropped_images/31_crop_83.jpg
# Cropped and saved image: data/cropped_images/31_crop_84.jpg
# Cropped and saved image: data/cropped_images/31_crop_85.jpg
# Cropped and saved image: data/cropped_images/31_crop_86.jpg
# Cropped and saved image: data/cropped_images/31_crop_87.jpg
# Cropped and saved image: data/cropped_images/31_crop_88.jpg
# Total crops for 31.JPG: 88
# Cropped and saved image: data/cropped_images/48_crop_1.jpg
# Cropped and saved image: data/cropped_images/48_crop_2.jpg
# Cropped and saved image: data/cropped_images/48_crop_3.jpg
# Cropped and saved image: data/cropped_images/48_crop_4.jpg
# Cropped and saved image: data/cropped_images/48_crop_5.jpg
# Cropped and saved image: data/cropped_images/48_crop_6.jpg
# Cropped and saved image: data/cropped_images/48_crop_7.jpg
# Cropped and saved image: data/cropped_images/48_crop_8.jpg
# Cropped and saved image: data/cropped_images/48_crop_9.jpg
# Cropped and saved image: data/cropped_images/48_crop_10.jpg
# Cropped and saved image: data/cropped_images/48_crop_11.jpg
# Cropped and saved image: data/cropped_images/48_crop_12.jpg
# Cropped and saved image: data/cropped_images/48_crop_13.jpg
# Cropped and saved image: data/cropped_images/48_crop_14.jpg
# Cropped and saved image: data/cropped_images/48_crop_15.jpg
# Cropped and saved image: data/cropped_images/48_crop_16.jpg
# Cropped and saved image: data/cropped_images/48_crop_17.jpg
# Cropped and saved image: data/cropped_images/48_crop_18.jpg
# Cropped and saved image: data/cropped_images/48_crop_19.jpg
# Cropped and saved image: data/cropped_images/48_crop_20.jpg
# Cropped and saved image: data/cropped_images/48_crop_21.jpg
# Cropped and saved image: data/cropped_images/48_crop_22.jpg
# Cropped and saved image: data/cropped_images/48_crop_23.jpg
# Cropped and saved image: data/cropped_images/48_crop_24.jpg
# Cropped and saved image: data/cropped_images/48_crop_25.jpg
# Cropped and saved image: data/cropped_images/48_crop_26.jpg
# Cropped and saved image: data/cropped_images/48_crop_27.jpg
# Cropped and saved image: data/cropped_images/48_crop_28.jpg
# Cropped and saved image: data/cropped_images/48_crop_29.jpg
# Cropped and saved image: data/cropped_images/48_crop_30.jpg
# Cropped and saved image: data/cropped_images/48_crop_31.jpg
# Cropped and saved image: data/cropped_images/48_crop_32.jpg
# Cropped and saved image: data/cropped_images/48_crop_33.jpg
# Cropped and saved image: data/cropped_images/48_crop_34.jpg
# Cropped and saved image: data/cropped_images/48_crop_35.jpg
# Cropped and saved image: data/cropped_images/48_crop_36.jpg
# Cropped and saved image: data/cropped_images/48_crop_37.jpg
# Cropped and saved image: data/cropped_images/48_crop_38.jpg
# Cropped and saved image: data/cropped_images/48_crop_39.jpg
# Cropped and saved image: data/cropped_images/48_crop_40.jpg
# Cropped and saved image: data/cropped_images/48_crop_41.jpg
# Cropped and saved image: data/cropped_images/48_crop_42.jpg
# Cropped and saved image: data/cropped_images/48_crop_43.jpg
# Cropped and saved image: data/cropped_images/48_crop_44.jpg
# Cropped and saved image: data/cropped_images/48_crop_45.jpg
# Cropped and saved image: data/cropped_images/48_crop_46.jpg
# Cropped and saved image: data/cropped_images/48_crop_47.jpg
# Cropped and saved image: data/cropped_images/48_crop_48.jpg
# Cropped and saved image: data/cropped_images/48_crop_49.jpg
# Cropped and saved image: data/cropped_images/48_crop_50.jpg
# Cropped and saved image: data/cropped_images/48_crop_51.jpg
# Cropped and saved image: data/cropped_images/48_crop_52.jpg
# Cropped and saved image: data/cropped_images/48_crop_53.jpg
# Cropped and saved image: data/cropped_images/48_crop_54.jpg
# Cropped and saved image: data/cropped_images/48_crop_55.jpg
# Cropped and saved image: data/cropped_images/48_crop_56.jpg
# Cropped and saved image: data/cropped_images/48_crop_57.jpg
# Cropped and saved image: data/cropped_images/48_crop_58.jpg
# Cropped and saved image: data/cropped_images/48_crop_59.jpg
# Cropped and saved image: data/cropped_images/48_crop_60.jpg
# Cropped and saved image: data/cropped_images/48_crop_61.jpg
# Cropped and saved image: data/cropped_images/48_crop_62.jpg
# Cropped and saved image: data/cropped_images/48_crop_63.jpg
# Cropped and saved image: data/cropped_images/48_crop_64.jpg
# Cropped and saved image: data/cropped_images/48_crop_65.jpg
# Cropped and saved image: data/cropped_images/48_crop_66.jpg
# Cropped and saved image: data/cropped_images/48_crop_67.jpg
# Cropped and saved image: data/cropped_images/48_crop_68.jpg
# Cropped and saved image: data/cropped_images/48_crop_69.jpg
# Cropped and saved image: data/cropped_images/48_crop_70.jpg
# Cropped and saved image: data/cropped_images/48_crop_71.jpg
# Cropped and saved image: data/cropped_images/48_crop_72.jpg
# Cropped and saved image: data/cropped_images/48_crop_73.jpg
# Cropped and saved image: data/cropped_images/48_crop_74.jpg
# Cropped and saved image: data/cropped_images/48_crop_75.jpg
# Cropped and saved image: data/cropped_images/48_crop_76.jpg
# Cropped and saved image: data/cropped_images/48_crop_77.jpg
# Cropped and saved image: data/cropped_images/48_crop_78.jpg
# Cropped and saved image: data/cropped_images/48_crop_79.jpg
# Cropped and saved image: data/cropped_images/48_crop_80.jpg
# Cropped and saved image: data/cropped_images/48_crop_81.jpg
# Cropped and saved image: data/cropped_images/48_crop_82.jpg
# Cropped and saved image: data/cropped_images/48_crop_83.jpg
# Cropped and saved image: data/cropped_images/48_crop_84.jpg
# Cropped and saved image: data/cropped_images/48_crop_85.jpg
# Cropped and saved image: data/cropped_images/48_crop_86.jpg
# Cropped and saved image: data/cropped_images/48_crop_87.jpg
# Cropped and saved image: data/cropped_images/48_crop_88.jpg
# Total crops for 48.JPG: 88
# Cropped and saved image: data/cropped_images/52_crop_1.jpg
# Cropped and saved image: data/cropped_images/52_crop_2.jpg
# Cropped and saved image: data/cropped_images/52_crop_3.jpg
# Cropped and saved image: data/cropped_images/52_crop_4.jpg
# Cropped and saved image: data/cropped_images/52_crop_5.jpg
# Cropped and saved image: data/cropped_images/52_crop_6.jpg
# Cropped and saved image: data/cropped_images/52_crop_7.jpg
# Cropped and saved image: data/cropped_images/52_crop_8.jpg
# Cropped and saved image: data/cropped_images/52_crop_9.jpg
# Cropped and saved image: data/cropped_images/52_crop_10.jpg
# Cropped and saved image: data/cropped_images/52_crop_11.jpg
# Cropped and saved image: data/cropped_images/52_crop_12.jpg
# Cropped and saved image: data/cropped_images/52_crop_13.jpg
# Cropped and saved image: data/cropped_images/52_crop_14.jpg
# Cropped and saved image: data/cropped_images/52_crop_15.jpg
# Cropped and saved image: data/cropped_images/52_crop_16.jpg
# Cropped and saved image: data/cropped_images/52_crop_17.jpg
# Cropped and saved image: data/cropped_images/52_crop_18.jpg
# Cropped and saved image: data/cropped_images/52_crop_19.jpg
# Cropped and saved image: data/cropped_images/52_crop_20.jpg
# Cropped and saved image: data/cropped_images/52_crop_21.jpg
# Cropped and saved image: data/cropped_images/52_crop_22.jpg
# Cropped and saved image: data/cropped_images/52_crop_23.jpg
# Cropped and saved image: data/cropped_images/52_crop_24.jpg
# Cropped and saved image: data/cropped_images/52_crop_25.jpg
# Cropped and saved image: data/cropped_images/52_crop_26.jpg
# Cropped and saved image: data/cropped_images/52_crop_27.jpg
# Cropped and saved image: data/cropped_images/52_crop_28.jpg
# Cropped and saved image: data/cropped_images/52_crop_29.jpg
# Cropped and saved image: data/cropped_images/52_crop_30.jpg
# Cropped and saved image: data/cropped_images/52_crop_31.jpg
# Cropped and saved image: data/cropped_images/52_crop_32.jpg
# Cropped and saved image: data/cropped_images/52_crop_33.jpg
# Cropped and saved image: data/cropped_images/52_crop_34.jpg
# Cropped and saved image: data/cropped_images/52_crop_35.jpg
# Cropped and saved image: data/cropped_images/52_crop_36.jpg
# Cropped and saved image: data/cropped_images/52_crop_37.jpg
# Cropped and saved image: data/cropped_images/52_crop_38.jpg
# Cropped and saved image: data/cropped_images/52_crop_39.jpg
# Cropped and saved image: data/cropped_images/52_crop_40.jpg
# Cropped and saved image: data/cropped_images/52_crop_41.jpg
# Cropped and saved image: data/cropped_images/52_crop_42.jpg
# Cropped and saved image: data/cropped_images/52_crop_43.jpg
# Cropped and saved image: data/cropped_images/52_crop_44.jpg
# Cropped and saved image: data/cropped_images/52_crop_45.jpg
# Cropped and saved image: data/cropped_images/52_crop_46.jpg
# Cropped and saved image: data/cropped_images/52_crop_47.jpg
# Cropped and saved image: data/cropped_images/52_crop_48.jpg
# Cropped and saved image: data/cropped_images/52_crop_49.jpg
# Cropped and saved image: data/cropped_images/52_crop_50.jpg
# Cropped and saved image: data/cropped_images/52_crop_51.jpg
# Cropped and saved image: data/cropped_images/52_crop_52.jpg
# Cropped and saved image: data/cropped_images/52_crop_53.jpg
# Cropped and saved image: data/cropped_images/52_crop_54.jpg
# Cropped and saved image: data/cropped_images/52_crop_55.jpg
# Cropped and saved image: data/cropped_images/52_crop_56.jpg
# Cropped and saved image: data/cropped_images/52_crop_57.jpg
# Cropped and saved image: data/cropped_images/52_crop_58.jpg
# Cropped and saved image: data/cropped_images/52_crop_59.jpg
# Cropped and saved image: data/cropped_images/52_crop_60.jpg
# Cropped and saved image: data/cropped_images/52_crop_61.jpg
# Cropped and saved image: data/cropped_images/52_crop_62.jpg
# Cropped and saved image: data/cropped_images/52_crop_63.jpg
# Cropped and saved image: data/cropped_images/52_crop_64.jpg
# Cropped and saved image: data/cropped_images/52_crop_65.jpg
# Cropped and saved image: data/cropped_images/52_crop_66.jpg
# Cropped and saved image: data/cropped_images/52_crop_67.jpg
# Cropped and saved image: data/cropped_images/52_crop_68.jpg
# Cropped and saved image: data/cropped_images/52_crop_69.jpg
# Cropped and saved image: data/cropped_images/52_crop_70.jpg
# Cropped and saved image: data/cropped_images/52_crop_71.jpg
# Cropped and saved image: data/cropped_images/52_crop_72.jpg
# Cropped and saved image: data/cropped_images/52_crop_73.jpg
# Cropped and saved image: data/cropped_images/52_crop_74.jpg
# Cropped and saved image: data/cropped_images/52_crop_75.jpg
# Cropped and saved image: data/cropped_images/52_crop_76.jpg
# Cropped and saved image: data/cropped_images/52_crop_77.jpg
# Cropped and saved image: data/cropped_images/52_crop_78.jpg
# Cropped and saved image: data/cropped_images/52_crop_79.jpg
# Cropped and saved image: data/cropped_images/52_crop_80.jpg
# Cropped and saved image: data/cropped_images/52_crop_81.jpg
# Cropped and saved image: data/cropped_images/52_crop_82.jpg
# Cropped and saved image: data/cropped_images/52_crop_83.jpg
# Cropped and saved image: data/cropped_images/52_crop_84.jpg
# Cropped and saved image: data/cropped_images/52_crop_85.jpg
# Cropped and saved image: data/cropped_images/52_crop_86.jpg
# Cropped and saved image: data/cropped_images/52_crop_87.jpg
# Cropped and saved image: data/cropped_images/52_crop_88.jpg
# Total crops for 52.JPG: 88
# Cropped and saved image: data/cropped_images/56_crop_1.jpg
# Cropped and saved image: data/cropped_images/56_crop_2.jpg
# Cropped and saved image: data/cropped_images/56_crop_3.jpg
# Cropped and saved image: data/cropped_images/56_crop_4.jpg
# Cropped and saved image: data/cropped_images/56_crop_5.jpg
# Cropped and saved image: data/cropped_images/56_crop_6.jpg
# Cropped and saved image: data/cropped_images/56_crop_7.jpg
# Cropped and saved image: data/cropped_images/56_crop_8.jpg
# Cropped and saved image: data/cropped_images/56_crop_9.jpg
# Cropped and saved image: data/cropped_images/56_crop_10.jpg
# Cropped and saved image: data/cropped_images/56_crop_11.jpg
# Cropped and saved image: data/cropped_images/56_crop_12.jpg
# Cropped and saved image: data/cropped_images/56_crop_13.jpg
# Cropped and saved image: data/cropped_images/56_crop_14.jpg
# Cropped and saved image: data/cropped_images/56_crop_15.jpg
# Cropped and saved image: data/cropped_images/56_crop_16.jpg
# Cropped and saved image: data/cropped_images/56_crop_17.jpg
# Cropped and saved image: data/cropped_images/56_crop_18.jpg
# Cropped and saved image: data/cropped_images/56_crop_19.jpg
# Cropped and saved image: data/cropped_images/56_crop_20.jpg
# Cropped and saved image: data/cropped_images/56_crop_21.jpg
# Cropped and saved image: data/cropped_images/56_crop_22.jpg
# Cropped and saved image: data/cropped_images/56_crop_23.jpg
# Cropped and saved image: data/cropped_images/56_crop_24.jpg
# Cropped and saved image: data/cropped_images/56_crop_25.jpg
# Cropped and saved image: data/cropped_images/56_crop_26.jpg
# Cropped and saved image: data/cropped_images/56_crop_27.jpg
# Cropped and saved image: data/cropped_images/56_crop_28.jpg
# Cropped and saved image: data/cropped_images/56_crop_29.jpg
# Cropped and saved image: data/cropped_images/56_crop_30.jpg
# Cropped and saved image: data/cropped_images/56_crop_31.jpg
# Cropped and saved image: data/cropped_images/56_crop_32.jpg
# Cropped and saved image: data/cropped_images/56_crop_33.jpg
# Cropped and saved image: data/cropped_images/56_crop_34.jpg
# Cropped and saved image: data/cropped_images/56_crop_35.jpg
# Cropped and saved image: data/cropped_images/56_crop_36.jpg
# Cropped and saved image: data/cropped_images/56_crop_37.jpg
# Cropped and saved image: data/cropped_images/56_crop_38.jpg
# Cropped and saved image: data/cropped_images/56_crop_39.jpg
# Cropped and saved image: data/cropped_images/56_crop_40.jpg
# Cropped and saved image: data/cropped_images/56_crop_41.jpg
# Cropped and saved image: data/cropped_images/56_crop_42.jpg
# Cropped and saved image: data/cropped_images/56_crop_43.jpg
# Cropped and saved image: data/cropped_images/56_crop_44.jpg
# Cropped and saved image: data/cropped_images/56_crop_45.jpg
# Cropped and saved image: data/cropped_images/56_crop_46.jpg
# Cropped and saved image: data/cropped_images/56_crop_47.jpg
# Cropped and saved image: data/cropped_images/56_crop_48.jpg
# Cropped and saved image: data/cropped_images/56_crop_49.jpg
# Cropped and saved image: data/cropped_images/56_crop_50.jpg
# Cropped and saved image: data/cropped_images/56_crop_51.jpg
# Cropped and saved image: data/cropped_images/56_crop_52.jpg
# Cropped and saved image: data/cropped_images/56_crop_53.jpg
# Cropped and saved image: data/cropped_images/56_crop_54.jpg
# Cropped and saved image: data/cropped_images/56_crop_55.jpg
# Cropped and saved image: data/cropped_images/56_crop_56.jpg
# Cropped and saved image: data/cropped_images/56_crop_57.jpg
# Cropped and saved image: data/cropped_images/56_crop_58.jpg
# Cropped and saved image: data/cropped_images/56_crop_59.jpg
# Cropped and saved image: data/cropped_images/56_crop_60.jpg
# Cropped and saved image: data/cropped_images/56_crop_61.jpg
# Cropped and saved image: data/cropped_images/56_crop_62.jpg
# Cropped and saved image: data/cropped_images/56_crop_63.jpg
# Cropped and saved image: data/cropped_images/56_crop_64.jpg
# Cropped and saved image: data/cropped_images/56_crop_65.jpg
# Cropped and saved image: data/cropped_images/56_crop_66.jpg
# Cropped and saved image: data/cropped_images/56_crop_67.jpg
# Cropped and saved image: data/cropped_images/56_crop_68.jpg
# Cropped and saved image: data/cropped_images/56_crop_69.jpg
# Cropped and saved image: data/cropped_images/56_crop_70.jpg
# Cropped and saved image: data/cropped_images/56_crop_71.jpg
# Cropped and saved image: data/cropped_images/56_crop_72.jpg
# Cropped and saved image: data/cropped_images/56_crop_73.jpg
# Cropped and saved image: data/cropped_images/56_crop_74.jpg
# Cropped and saved image: data/cropped_images/56_crop_75.jpg
# Cropped and saved image: data/cropped_images/56_crop_76.jpg
# Cropped and saved image: data/cropped_images/56_crop_77.jpg
# Cropped and saved image: data/cropped_images/56_crop_78.jpg
# Cropped and saved image: data/cropped_images/56_crop_79.jpg
# Cropped and saved image: data/cropped_images/56_crop_80.jpg
# Cropped and saved image: data/cropped_images/56_crop_81.jpg
# Cropped and saved image: data/cropped_images/56_crop_82.jpg
# Cropped and saved image: data/cropped_images/56_crop_83.jpg
# Cropped and saved image: data/cropped_images/56_crop_84.jpg
# Cropped and saved image: data/cropped_images/56_crop_85.jpg
# Cropped and saved image: data/cropped_images/56_crop_86.jpg
# Cropped and saved image: data/cropped_images/56_crop_87.jpg
# Cropped and saved image: data/cropped_images/56_crop_88.jpg
# Total crops for 56.JPG: 88
# Cropped and saved image: data/cropped_images/67_crop_1.jpg
# Cropped and saved image: data/cropped_images/67_crop_2.jpg
# Cropped and saved image: data/cropped_images/67_crop_3.jpg
# Cropped and saved image: data/cropped_images/67_crop_4.jpg
# Cropped and saved image: data/cropped_images/67_crop_5.jpg
# Cropped and saved image: data/cropped_images/67_crop_6.jpg
# Cropped and saved image: data/cropped_images/67_crop_7.jpg
# Cropped and saved image: data/cropped_images/67_crop_8.jpg
# Cropped and saved image: data/cropped_images/67_crop_9.jpg
# Cropped and saved image: data/cropped_images/67_crop_10.jpg
# Cropped and saved image: data/cropped_images/67_crop_11.jpg
# Cropped and saved image: data/cropped_images/67_crop_12.jpg
# Cropped and saved image: data/cropped_images/67_crop_13.jpg
# Cropped and saved image: data/cropped_images/67_crop_14.jpg
# Cropped and saved image: data/cropped_images/67_crop_15.jpg
# Cropped and saved image: data/cropped_images/67_crop_16.jpg
# Cropped and saved image: data/cropped_images/67_crop_17.jpg
# Cropped and saved image: data/cropped_images/67_crop_18.jpg
# Cropped and saved image: data/cropped_images/67_crop_19.jpg
# Cropped and saved image: data/cropped_images/67_crop_20.jpg
# Cropped and saved image: data/cropped_images/67_crop_21.jpg
# Cropped and saved image: data/cropped_images/67_crop_22.jpg
# Cropped and saved image: data/cropped_images/67_crop_23.jpg
# Cropped and saved image: data/cropped_images/67_crop_24.jpg
# Cropped and saved image: data/cropped_images/67_crop_25.jpg
# Cropped and saved image: data/cropped_images/67_crop_26.jpg
# Cropped and saved image: data/cropped_images/67_crop_27.jpg
# Cropped and saved image: data/cropped_images/67_crop_28.jpg
# Cropped and saved image: data/cropped_images/67_crop_29.jpg
# Cropped and saved image: data/cropped_images/67_crop_30.jpg
# Cropped and saved image: data/cropped_images/67_crop_31.jpg
# Cropped and saved image: data/cropped_images/67_crop_32.jpg
# Cropped and saved image: data/cropped_images/67_crop_33.jpg
# Cropped and saved image: data/cropped_images/67_crop_34.jpg
# Cropped and saved image: data/cropped_images/67_crop_35.jpg
# Cropped and saved image: data/cropped_images/67_crop_36.jpg
# Cropped and saved image: data/cropped_images/67_crop_37.jpg
# Cropped and saved image: data/cropped_images/67_crop_38.jpg
# Cropped and saved image: data/cropped_images/67_crop_39.jpg
# Cropped and saved image: data/cropped_images/67_crop_40.jpg
# Cropped and saved image: data/cropped_images/67_crop_41.jpg
# Cropped and saved image: data/cropped_images/67_crop_42.jpg
# Cropped and saved image: data/cropped_images/67_crop_43.jpg
# Cropped and saved image: data/cropped_images/67_crop_44.jpg
# Cropped and saved image: data/cropped_images/67_crop_45.jpg
# Cropped and saved image: data/cropped_images/67_crop_46.jpg
# Cropped and saved image: data/cropped_images/67_crop_47.jpg
# Cropped and saved image: data/cropped_images/67_crop_48.jpg
# Cropped and saved image: data/cropped_images/67_crop_49.jpg
# Cropped and saved image: data/cropped_images/67_crop_50.jpg
# Cropped and saved image: data/cropped_images/67_crop_51.jpg
# Cropped and saved image: data/cropped_images/67_crop_52.jpg
# Cropped and saved image: data/cropped_images/67_crop_53.jpg
# Cropped and saved image: data/cropped_images/67_crop_54.jpg
# Cropped and saved image: data/cropped_images/67_crop_55.jpg
# Cropped and saved image: data/cropped_images/67_crop_56.jpg
# Cropped and saved image: data/cropped_images/67_crop_57.jpg
# Cropped and saved image: data/cropped_images/67_crop_58.jpg
# Cropped and saved image: data/cropped_images/67_crop_59.jpg
# Cropped and saved image: data/cropped_images/67_crop_60.jpg
# Cropped and saved image: data/cropped_images/67_crop_61.jpg
# Cropped and saved image: data/cropped_images/67_crop_62.jpg
# Cropped and saved image: data/cropped_images/67_crop_63.jpg
# Cropped and saved image: data/cropped_images/67_crop_64.jpg
# Cropped and saved image: data/cropped_images/67_crop_65.jpg
# Cropped and saved image: data/cropped_images/67_crop_66.jpg
# Cropped and saved image: data/cropped_images/67_crop_67.jpg
# Cropped and saved image: data/cropped_images/67_crop_68.jpg
# Cropped and saved image: data/cropped_images/67_crop_69.jpg
# Cropped and saved image: data/cropped_images/67_crop_70.jpg
# Cropped and saved image: data/cropped_images/67_crop_71.jpg
# Cropped and saved image: data/cropped_images/67_crop_72.jpg
# Cropped and saved image: data/cropped_images/67_crop_73.jpg
# Cropped and saved image: data/cropped_images/67_crop_74.jpg
# Cropped and saved image: data/cropped_images/67_crop_75.jpg
# Cropped and saved image: data/cropped_images/67_crop_76.jpg
# Cropped and saved image: data/cropped_images/67_crop_77.jpg
# Cropped and saved image: data/cropped_images/67_crop_78.jpg
# Cropped and saved image: data/cropped_images/67_crop_79.jpg
# Cropped and saved image: data/cropped_images/67_crop_80.jpg
# Cropped and saved image: data/cropped_images/67_crop_81.jpg
# Cropped and saved image: data/cropped_images/67_crop_82.jpg
# Cropped and saved image: data/cropped_images/67_crop_83.jpg
# Cropped and saved image: data/cropped_images/67_crop_84.jpg
# Cropped and saved image: data/cropped_images/67_crop_85.jpg
# Cropped and saved image: data/cropped_images/67_crop_86.jpg
# Cropped and saved image: data/cropped_images/67_crop_87.jpg
# Cropped and saved image: data/cropped_images/67_crop_88.jpg
# Total crops for 67.JPG: 88
# Cropped and saved image: data/cropped_images/60_crop_1.jpg
# Cropped and saved image: data/cropped_images/60_crop_2.jpg
# Cropped and saved image: data/cropped_images/60_crop_3.jpg
# Cropped and saved image: data/cropped_images/60_crop_4.jpg
# Cropped and saved image: data/cropped_images/60_crop_5.jpg
# Cropped and saved image: data/cropped_images/60_crop_6.jpg
# Cropped and saved image: data/cropped_images/60_crop_7.jpg
# Cropped and saved image: data/cropped_images/60_crop_8.jpg
# Cropped and saved image: data/cropped_images/60_crop_9.jpg
# Cropped and saved image: data/cropped_images/60_crop_10.jpg
# Cropped and saved image: data/cropped_images/60_crop_11.jpg
# Cropped and saved image: data/cropped_images/60_crop_12.jpg
# Cropped and saved image: data/cropped_images/60_crop_13.jpg
# Cropped and saved image: data/cropped_images/60_crop_14.jpg
# Cropped and saved image: data/cropped_images/60_crop_15.jpg
# Cropped and saved image: data/cropped_images/60_crop_16.jpg
# Cropped and saved image: data/cropped_images/60_crop_17.jpg
# Cropped and saved image: data/cropped_images/60_crop_18.jpg
# Cropped and saved image: data/cropped_images/60_crop_19.jpg
# Cropped and saved image: data/cropped_images/60_crop_20.jpg
# Cropped and saved image: data/cropped_images/60_crop_21.jpg
# Cropped and saved image: data/cropped_images/60_crop_22.jpg
# Cropped and saved image: data/cropped_images/60_crop_23.jpg
# Cropped and saved image: data/cropped_images/60_crop_24.jpg
# Cropped and saved image: data/cropped_images/60_crop_25.jpg
# Cropped and saved image: data/cropped_images/60_crop_26.jpg
# Cropped and saved image: data/cropped_images/60_crop_27.jpg
# Cropped and saved image: data/cropped_images/60_crop_28.jpg
# Cropped and saved image: data/cropped_images/60_crop_29.jpg
# Cropped and saved image: data/cropped_images/60_crop_30.jpg
# Cropped and saved image: data/cropped_images/60_crop_31.jpg
# Cropped and saved image: data/cropped_images/60_crop_32.jpg
# Cropped and saved image: data/cropped_images/60_crop_33.jpg
# Cropped and saved image: data/cropped_images/60_crop_34.jpg
# Cropped and saved image: data/cropped_images/60_crop_35.jpg
# Cropped and saved image: data/cropped_images/60_crop_36.jpg
# Cropped and saved image: data/cropped_images/60_crop_37.jpg
# Cropped and saved image: data/cropped_images/60_crop_38.jpg
# Cropped and saved image: data/cropped_images/60_crop_39.jpg
# Cropped and saved image: data/cropped_images/60_crop_40.jpg
# Cropped and saved image: data/cropped_images/60_crop_41.jpg
# Cropped and saved image: data/cropped_images/60_crop_42.jpg
# Cropped and saved image: data/cropped_images/60_crop_43.jpg
# Cropped and saved image: data/cropped_images/60_crop_44.jpg
# Cropped and saved image: data/cropped_images/60_crop_45.jpg
# Cropped and saved image: data/cropped_images/60_crop_46.jpg
# Cropped and saved image: data/cropped_images/60_crop_47.jpg
# Cropped and saved image: data/cropped_images/60_crop_48.jpg
# Cropped and saved image: data/cropped_images/60_crop_49.jpg
# Cropped and saved image: data/cropped_images/60_crop_50.jpg
# Cropped and saved image: data/cropped_images/60_crop_51.jpg
# Cropped and saved image: data/cropped_images/60_crop_52.jpg
# Cropped and saved image: data/cropped_images/60_crop_53.jpg
# Cropped and saved image: data/cropped_images/60_crop_54.jpg
# Cropped and saved image: data/cropped_images/60_crop_55.jpg
# Cropped and saved image: data/cropped_images/60_crop_56.jpg
# Cropped and saved image: data/cropped_images/60_crop_57.jpg
# Cropped and saved image: data/cropped_images/60_crop_58.jpg
# Cropped and saved image: data/cropped_images/60_crop_59.jpg
# Cropped and saved image: data/cropped_images/60_crop_60.jpg
# Cropped and saved image: data/cropped_images/60_crop_61.jpg
# Cropped and saved image: data/cropped_images/60_crop_62.jpg
# Cropped and saved image: data/cropped_images/60_crop_63.jpg
# Cropped and saved image: data/cropped_images/60_crop_64.jpg
# Cropped and saved image: data/cropped_images/60_crop_65.jpg
# Cropped and saved image: data/cropped_images/60_crop_66.jpg
# Cropped and saved image: data/cropped_images/60_crop_67.jpg
# Cropped and saved image: data/cropped_images/60_crop_68.jpg
# Cropped and saved image: data/cropped_images/60_crop_69.jpg
# Cropped and saved image: data/cropped_images/60_crop_70.jpg
# Cropped and saved image: data/cropped_images/60_crop_71.jpg
# Cropped and saved image: data/cropped_images/60_crop_72.jpg
# Cropped and saved image: data/cropped_images/60_crop_73.jpg
# Cropped and saved image: data/cropped_images/60_crop_74.jpg
# Cropped and saved image: data/cropped_images/60_crop_75.jpg
# Cropped and saved image: data/cropped_images/60_crop_76.jpg
# Cropped and saved image: data/cropped_images/60_crop_77.jpg
# Cropped and saved image: data/cropped_images/60_crop_78.jpg
# Cropped and saved image: data/cropped_images/60_crop_79.jpg
# Cropped and saved image: data/cropped_images/60_crop_80.jpg
# Cropped and saved image: data/cropped_images/60_crop_81.jpg
# Cropped and saved image: data/cropped_images/60_crop_82.jpg
# Cropped and saved image: data/cropped_images/60_crop_83.jpg
# Cropped and saved image: data/cropped_images/60_crop_84.jpg
# Cropped and saved image: data/cropped_images/60_crop_85.jpg
# Cropped and saved image: data/cropped_images/60_crop_86.jpg
# Cropped and saved image: data/cropped_images/60_crop_87.jpg
# Cropped and saved image: data/cropped_images/60_crop_88.jpg
# Total crops for 60.JPG: 88
# Cropped and saved image: data/cropped_images/58_crop_1.jpg
# Cropped and saved image: data/cropped_images/58_crop_2.jpg
# Cropped and saved image: data/cropped_images/58_crop_3.jpg
# Cropped and saved image: data/cropped_images/58_crop_4.jpg
# Cropped and saved image: data/cropped_images/58_crop_5.jpg
# Cropped and saved image: data/cropped_images/58_crop_6.jpg
# Cropped and saved image: data/cropped_images/58_crop_7.jpg
# Cropped and saved image: data/cropped_images/58_crop_8.jpg
# Cropped and saved image: data/cropped_images/58_crop_9.jpg
# Cropped and saved image: data/cropped_images/58_crop_10.jpg
# Cropped and saved image: data/cropped_images/58_crop_11.jpg
# Cropped and saved image: data/cropped_images/58_crop_12.jpg
# Cropped and saved image: data/cropped_images/58_crop_13.jpg
# Cropped and saved image: data/cropped_images/58_crop_14.jpg
# Cropped and saved image: data/cropped_images/58_crop_15.jpg
# Cropped and saved image: data/cropped_images/58_crop_16.jpg
# Cropped and saved image: data/cropped_images/58_crop_17.jpg
# Cropped and saved image: data/cropped_images/58_crop_18.jpg
# Cropped and saved image: data/cropped_images/58_crop_19.jpg
# Cropped and saved image: data/cropped_images/58_crop_20.jpg
# Cropped and saved image: data/cropped_images/58_crop_21.jpg
# Cropped and saved image: data/cropped_images/58_crop_22.jpg
# Cropped and saved image: data/cropped_images/58_crop_23.jpg
# Cropped and saved image: data/cropped_images/58_crop_24.jpg
# Cropped and saved image: data/cropped_images/58_crop_25.jpg
# Cropped and saved image: data/cropped_images/58_crop_26.jpg
# Cropped and saved image: data/cropped_images/58_crop_27.jpg
# Cropped and saved image: data/cropped_images/58_crop_28.jpg
# Cropped and saved image: data/cropped_images/58_crop_29.jpg
# Cropped and saved image: data/cropped_images/58_crop_30.jpg
# Cropped and saved image: data/cropped_images/58_crop_31.jpg
# Cropped and saved image: data/cropped_images/58_crop_32.jpg
# Cropped and saved image: data/cropped_images/58_crop_33.jpg
# Cropped and saved image: data/cropped_images/58_crop_34.jpg
# Cropped and saved image: data/cropped_images/58_crop_35.jpg
# Cropped and saved image: data/cropped_images/58_crop_36.jpg
# Cropped and saved image: data/cropped_images/58_crop_37.jpg
# Cropped and saved image: data/cropped_images/58_crop_38.jpg
# Cropped and saved image: data/cropped_images/58_crop_39.jpg
# Cropped and saved image: data/cropped_images/58_crop_40.jpg
# Cropped and saved image: data/cropped_images/58_crop_41.jpg
# Cropped and saved image: data/cropped_images/58_crop_42.jpg
# Cropped and saved image: data/cropped_images/58_crop_43.jpg
# Cropped and saved image: data/cropped_images/58_crop_44.jpg
# Cropped and saved image: data/cropped_images/58_crop_45.jpg
# Cropped and saved image: data/cropped_images/58_crop_46.jpg
# Cropped and saved image: data/cropped_images/58_crop_47.jpg
# Cropped and saved image: data/cropped_images/58_crop_48.jpg
# Cropped and saved image: data/cropped_images/58_crop_49.jpg
# Cropped and saved image: data/cropped_images/58_crop_50.jpg
# Cropped and saved image: data/cropped_images/58_crop_51.jpg
# Cropped and saved image: data/cropped_images/58_crop_52.jpg
# Cropped and saved image: data/cropped_images/58_crop_53.jpg
# Cropped and saved image: data/cropped_images/58_crop_54.jpg
# Cropped and saved image: data/cropped_images/58_crop_55.jpg
# Cropped and saved image: data/cropped_images/58_crop_56.jpg
# Cropped and saved image: data/cropped_images/58_crop_57.jpg
# Cropped and saved image: data/cropped_images/58_crop_58.jpg
# Cropped and saved image: data/cropped_images/58_crop_59.jpg
# Cropped and saved image: data/cropped_images/58_crop_60.jpg
# Cropped and saved image: data/cropped_images/58_crop_61.jpg
# Cropped and saved image: data/cropped_images/58_crop_62.jpg
# Cropped and saved image: data/cropped_images/58_crop_63.jpg
# Cropped and saved image: data/cropped_images/58_crop_64.jpg
# Cropped and saved image: data/cropped_images/58_crop_65.jpg
# Cropped and saved image: data/cropped_images/58_crop_66.jpg
# Cropped and saved image: data/cropped_images/58_crop_67.jpg
# Cropped and saved image: data/cropped_images/58_crop_68.jpg
# Cropped and saved image: data/cropped_images/58_crop_69.jpg
# Cropped and saved image: data/cropped_images/58_crop_70.jpg
# Cropped and saved image: data/cropped_images/58_crop_71.jpg
# Cropped and saved image: data/cropped_images/58_crop_72.jpg
# Cropped and saved image: data/cropped_images/58_crop_73.jpg
# Cropped and saved image: data/cropped_images/58_crop_74.jpg
# Cropped and saved image: data/cropped_images/58_crop_75.jpg
# Cropped and saved image: data/cropped_images/58_crop_76.jpg
# Cropped and saved image: data/cropped_images/58_crop_77.jpg
# Cropped and saved image: data/cropped_images/58_crop_78.jpg
# Cropped and saved image: data/cropped_images/58_crop_79.jpg
# Cropped and saved image: data/cropped_images/58_crop_80.jpg
# Cropped and saved image: data/cropped_images/58_crop_81.jpg
# Cropped and saved image: data/cropped_images/58_crop_82.jpg
# Cropped and saved image: data/cropped_images/58_crop_83.jpg
# Cropped and saved image: data/cropped_images/58_crop_84.jpg
# Cropped and saved image: data/cropped_images/58_crop_85.jpg
# Cropped and saved image: data/cropped_images/58_crop_86.jpg
# Cropped and saved image: data/cropped_images/58_crop_87.jpg
# Cropped and saved image: data/cropped_images/58_crop_88.jpg
# Total crops for 58.JPG: 88
# Cropped and saved image: data/cropped_images/65_crop_1.jpg
# Cropped and saved image: data/cropped_images/65_crop_2.jpg
# Cropped and saved image: data/cropped_images/65_crop_3.jpg
# Cropped and saved image: data/cropped_images/65_crop_4.jpg
# Cropped and saved image: data/cropped_images/65_crop_5.jpg
# Cropped and saved image: data/cropped_images/65_crop_6.jpg
# Cropped and saved image: data/cropped_images/65_crop_7.jpg
# Cropped and saved image: data/cropped_images/65_crop_8.jpg
# Cropped and saved image: data/cropped_images/65_crop_9.jpg
# Cropped and saved image: data/cropped_images/65_crop_10.jpg
# Cropped and saved image: data/cropped_images/65_crop_11.jpg
# Cropped and saved image: data/cropped_images/65_crop_12.jpg
# Cropped and saved image: data/cropped_images/65_crop_13.jpg
# Cropped and saved image: data/cropped_images/65_crop_14.jpg
# Cropped and saved image: data/cropped_images/65_crop_15.jpg
# Cropped and saved image: data/cropped_images/65_crop_16.jpg
# Cropped and saved image: data/cropped_images/65_crop_17.jpg
# Cropped and saved image: data/cropped_images/65_crop_18.jpg
# Cropped and saved image: data/cropped_images/65_crop_19.jpg
# Cropped and saved image: data/cropped_images/65_crop_20.jpg
# Cropped and saved image: data/cropped_images/65_crop_21.jpg
# Cropped and saved image: data/cropped_images/65_crop_22.jpg
# Cropped and saved image: data/cropped_images/65_crop_23.jpg
# Cropped and saved image: data/cropped_images/65_crop_24.jpg
# Cropped and saved image: data/cropped_images/65_crop_25.jpg
# Cropped and saved image: data/cropped_images/65_crop_26.jpg
# Cropped and saved image: data/cropped_images/65_crop_27.jpg
# Cropped and saved image: data/cropped_images/65_crop_28.jpg
# Cropped and saved image: data/cropped_images/65_crop_29.jpg
# Cropped and saved image: data/cropped_images/65_crop_30.jpg
# Cropped and saved image: data/cropped_images/65_crop_31.jpg
# Cropped and saved image: data/cropped_images/65_crop_32.jpg
# Cropped and saved image: data/cropped_images/65_crop_33.jpg
# Cropped and saved image: data/cropped_images/65_crop_34.jpg
# Cropped and saved image: data/cropped_images/65_crop_35.jpg
# Cropped and saved image: data/cropped_images/65_crop_36.jpg
# Cropped and saved image: data/cropped_images/65_crop_37.jpg
# Cropped and saved image: data/cropped_images/65_crop_38.jpg
# Cropped and saved image: data/cropped_images/65_crop_39.jpg
# Cropped and saved image: data/cropped_images/65_crop_40.jpg
# Cropped and saved image: data/cropped_images/65_crop_41.jpg
# Cropped and saved image: data/cropped_images/65_crop_42.jpg
# Cropped and saved image: data/cropped_images/65_crop_43.jpg
# Cropped and saved image: data/cropped_images/65_crop_44.jpg
# Cropped and saved image: data/cropped_images/65_crop_45.jpg
# Cropped and saved image: data/cropped_images/65_crop_46.jpg
# Cropped and saved image: data/cropped_images/65_crop_47.jpg
# Cropped and saved image: data/cropped_images/65_crop_48.jpg
# Cropped and saved image: data/cropped_images/65_crop_49.jpg
# Cropped and saved image: data/cropped_images/65_crop_50.jpg
# Cropped and saved image: data/cropped_images/65_crop_51.jpg
# Cropped and saved image: data/cropped_images/65_crop_52.jpg
# Cropped and saved image: data/cropped_images/65_crop_53.jpg
# Cropped and saved image: data/cropped_images/65_crop_54.jpg
# Cropped and saved image: data/cropped_images/65_crop_55.jpg
# Cropped and saved image: data/cropped_images/65_crop_56.jpg
# Cropped and saved image: data/cropped_images/65_crop_57.jpg
# Cropped and saved image: data/cropped_images/65_crop_58.jpg
# Cropped and saved image: data/cropped_images/65_crop_59.jpg
# Cropped and saved image: data/cropped_images/65_crop_60.jpg
# Cropped and saved image: data/cropped_images/65_crop_61.jpg
# Cropped and saved image: data/cropped_images/65_crop_62.jpg
# Cropped and saved image: data/cropped_images/65_crop_63.jpg
# Cropped and saved image: data/cropped_images/65_crop_64.jpg
# Cropped and saved image: data/cropped_images/65_crop_65.jpg
# Cropped and saved image: data/cropped_images/65_crop_66.jpg
# Cropped and saved image: data/cropped_images/65_crop_67.jpg
# Cropped and saved image: data/cropped_images/65_crop_68.jpg
# Cropped and saved image: data/cropped_images/65_crop_69.jpg
# Cropped and saved image: data/cropped_images/65_crop_70.jpg
# Cropped and saved image: data/cropped_images/65_crop_71.jpg
# Cropped and saved image: data/cropped_images/65_crop_72.jpg
# Cropped and saved image: data/cropped_images/65_crop_73.jpg
# Cropped and saved image: data/cropped_images/65_crop_74.jpg
# Cropped and saved image: data/cropped_images/65_crop_75.jpg
# Cropped and saved image: data/cropped_images/65_crop_76.jpg
# Cropped and saved image: data/cropped_images/65_crop_77.jpg
# Cropped and saved image: data/cropped_images/65_crop_78.jpg
# Cropped and saved image: data/cropped_images/65_crop_79.jpg
# Cropped and saved image: data/cropped_images/65_crop_80.jpg
# Cropped and saved image: data/cropped_images/65_crop_81.jpg
# Cropped and saved image: data/cropped_images/65_crop_82.jpg
# Cropped and saved image: data/cropped_images/65_crop_83.jpg
# Cropped and saved image: data/cropped_images/65_crop_84.jpg
# Cropped and saved image: data/cropped_images/65_crop_85.jpg
# Cropped and saved image: data/cropped_images/65_crop_86.jpg
# Cropped and saved image: data/cropped_images/65_crop_87.jpg
# Cropped and saved image: data/cropped_images/65_crop_88.jpg
# Total crops for 65.JPG: 88
# Cropped and saved image: data/cropped_images/66_crop_1.jpg
# Cropped and saved image: data/cropped_images/66_crop_2.jpg
# Cropped and saved image: data/cropped_images/66_crop_3.jpg
# Cropped and saved image: data/cropped_images/66_crop_4.jpg
# Cropped and saved image: data/cropped_images/66_crop_5.jpg
# Cropped and saved image: data/cropped_images/66_crop_6.jpg
# Cropped and saved image: data/cropped_images/66_crop_7.jpg
# Cropped and saved image: data/cropped_images/66_crop_8.jpg
# Cropped and saved image: data/cropped_images/66_crop_9.jpg
# Cropped and saved image: data/cropped_images/66_crop_10.jpg
# Cropped and saved image: data/cropped_images/66_crop_11.jpg
# Cropped and saved image: data/cropped_images/66_crop_12.jpg
# Cropped and saved image: data/cropped_images/66_crop_13.jpg
# Cropped and saved image: data/cropped_images/66_crop_14.jpg
# Cropped and saved image: data/cropped_images/66_crop_15.jpg
# Cropped and saved image: data/cropped_images/66_crop_16.jpg
# Cropped and saved image: data/cropped_images/66_crop_17.jpg
# Cropped and saved image: data/cropped_images/66_crop_18.jpg
# Cropped and saved image: data/cropped_images/66_crop_19.jpg
# Cropped and saved image: data/cropped_images/66_crop_20.jpg
# Cropped and saved image: data/cropped_images/66_crop_21.jpg
# Cropped and saved image: data/cropped_images/66_crop_22.jpg
# Cropped and saved image: data/cropped_images/66_crop_23.jpg
# Cropped and saved image: data/cropped_images/66_crop_24.jpg
# Cropped and saved image: data/cropped_images/66_crop_25.jpg
# Cropped and saved image: data/cropped_images/66_crop_26.jpg
# Cropped and saved image: data/cropped_images/66_crop_27.jpg
# Cropped and saved image: data/cropped_images/66_crop_28.jpg
# Cropped and saved image: data/cropped_images/66_crop_29.jpg
# Cropped and saved image: data/cropped_images/66_crop_30.jpg
# Cropped and saved image: data/cropped_images/66_crop_31.jpg
# Cropped and saved image: data/cropped_images/66_crop_32.jpg
# Cropped and saved image: data/cropped_images/66_crop_33.jpg
# Cropped and saved image: data/cropped_images/66_crop_34.jpg
# Cropped and saved image: data/cropped_images/66_crop_35.jpg
# Cropped and saved image: data/cropped_images/66_crop_36.jpg
# Cropped and saved image: data/cropped_images/66_crop_37.jpg
# Cropped and saved image: data/cropped_images/66_crop_38.jpg
# Cropped and saved image: data/cropped_images/66_crop_39.jpg
# Cropped and saved image: data/cropped_images/66_crop_40.jpg
# Cropped and saved image: data/cropped_images/66_crop_41.jpg
# Cropped and saved image: data/cropped_images/66_crop_42.jpg
# Cropped and saved image: data/cropped_images/66_crop_43.jpg
# Cropped and saved image: data/cropped_images/66_crop_44.jpg
# Cropped and saved image: data/cropped_images/66_crop_45.jpg
# Cropped and saved image: data/cropped_images/66_crop_46.jpg
# Cropped and saved image: data/cropped_images/66_crop_47.jpg
# Cropped and saved image: data/cropped_images/66_crop_48.jpg
# Cropped and saved image: data/cropped_images/66_crop_49.jpg
# Cropped and saved image: data/cropped_images/66_crop_50.jpg
# Cropped and saved image: data/cropped_images/66_crop_51.jpg
# Cropped and saved image: data/cropped_images/66_crop_52.jpg
# Cropped and saved image: data/cropped_images/66_crop_53.jpg
# Cropped and saved image: data/cropped_images/66_crop_54.jpg
# Cropped and saved image: data/cropped_images/66_crop_55.jpg
# Cropped and saved image: data/cropped_images/66_crop_56.jpg
# Cropped and saved image: data/cropped_images/66_crop_57.jpg
# Cropped and saved image: data/cropped_images/66_crop_58.jpg
# Cropped and saved image: data/cropped_images/66_crop_59.jpg
# Cropped and saved image: data/cropped_images/66_crop_60.jpg
# Cropped and saved image: data/cropped_images/66_crop_61.jpg
# Cropped and saved image: data/cropped_images/66_crop_62.jpg
# Cropped and saved image: data/cropped_images/66_crop_63.jpg
# Cropped and saved image: data/cropped_images/66_crop_64.jpg
# Cropped and saved image: data/cropped_images/66_crop_65.jpg
# Cropped and saved image: data/cropped_images/66_crop_66.jpg
# Cropped and saved image: data/cropped_images/66_crop_67.jpg
# Cropped and saved image: data/cropped_images/66_crop_68.jpg
# Cropped and saved image: data/cropped_images/66_crop_69.jpg
# Cropped and saved image: data/cropped_images/66_crop_70.jpg
# Cropped and saved image: data/cropped_images/66_crop_71.jpg
# Cropped and saved image: data/cropped_images/66_crop_72.jpg
# Cropped and saved image: data/cropped_images/66_crop_73.jpg
# Cropped and saved image: data/cropped_images/66_crop_74.jpg
# Cropped and saved image: data/cropped_images/66_crop_75.jpg
# Cropped and saved image: data/cropped_images/66_crop_76.jpg
# Cropped and saved image: data/cropped_images/66_crop_77.jpg
# Cropped and saved image: data/cropped_images/66_crop_78.jpg
# Cropped and saved image: data/cropped_images/66_crop_79.jpg
# Cropped and saved image: data/cropped_images/66_crop_80.jpg
# Cropped and saved image: data/cropped_images/66_crop_81.jpg
# Cropped and saved image: data/cropped_images/66_crop_82.jpg
# Cropped and saved image: data/cropped_images/66_crop_83.jpg
# Cropped and saved image: data/cropped_images/66_crop_84.jpg
# Cropped and saved image: data/cropped_images/66_crop_85.jpg
# Cropped and saved image: data/cropped_images/66_crop_86.jpg
# Cropped and saved image: data/cropped_images/66_crop_87.jpg
# Cropped and saved image: data/cropped_images/66_crop_88.jpg
# Total crops for 66.JPG: 88
# Cropped and saved image: data/cropped_images/68_crop_1.jpg
# Cropped and saved image: data/cropped_images/68_crop_2.jpg
# Cropped and saved image: data/cropped_images/68_crop_3.jpg
# Cropped and saved image: data/cropped_images/68_crop_4.jpg
# Cropped and saved image: data/cropped_images/68_crop_5.jpg
# ...
# Cropped and saved image: data/cropped_images/07_crop_88.jpg
# Total crops for 07.JPG: 88
# Cropped and saved image: data/cropped_images/14_crop_1.jpg
# Cropped and saved image: data/cropped_images/14_crop_2.jpg
# Cropped and saved image: data/cropped_images/14_crop_3.jpg
# Cropped and saved image: data/cropped_images/14_crop_4.jpg
# Cropped and saved image: data/cropped_images/14_crop_5.jpg
# Cropped and saved image: data/cropped_images/14_crop_6.jpg
# Cropped and saved image: data/cropped_images/14_crop_7.jpg
# Cropped and saved image: data/cropped_images/14_crop_8.jpg
# Cropped and saved image: data/cropped_images/14_crop_9.jpg
# Cropped and saved image: data/cropped_images/14_crop_10.jpg
# Cropped and saved image: data/cropped_images/14_crop_11.jpg
# Cropped and saved image: data/cropped_images/14_crop_12.jpg
# Cropped and saved image: data/cropped_images/14_crop_13.jpg
# Cropped and saved image: data/cropped_images/14_crop_14.jpg
# Cropped and saved image: data/cropped_images/14_crop_15.jpg
# Cropped and saved image: data/cropped_images/14_crop_16.jpg
# Cropped and saved image: data/cropped_images/14_crop_17.jpg
# Cropped and saved image: data/cropped_images/14_crop_18.jpg
# Cropped and saved image: data/cropped_images/14_crop_19.jpg
# Cropped and saved image: data/cropped_images/14_crop_20.jpg
# Cropped and saved image: data/cropped_images/14_crop_21.jpg
# Cropped and saved image: data/cropped_images/14_crop_22.jpg
# Cropped and saved image: data/cropped_images/14_crop_23.jpg
# Cropped and saved image: data/cropped_images/14_crop_24.jpg
# Cropped and saved image: data/cropped_images/14_crop_25.jpg
# Cropped and saved image: data/cropped_images/14_crop_26.jpg
# Cropped and saved image: data/cropped_images/14_crop_27.jpg
# Cropped and saved image: data/cropped_images/14_crop_28.jpg
# Cropped and saved image: data/cropped_images/14_crop_29.jpg
# Cropped and saved image: data/cropped_images/14_crop_30.jpg
# Cropped and saved image: data/cropped_images/14_crop_31.jpg
# Cropped and saved image: data/cropped_images/14_crop_32.jpg
# Cropped and saved image: data/cropped_images/14_crop_33.jpg
# Cropped and saved image: data/cropped_images/14_crop_34.jpg
# Cropped and saved image: data/cropped_images/14_crop_35.jpg
# Cropped and saved image: data/cropped_images/14_crop_36.jpg
# Cropped and saved image: data/cropped_images/14_crop_37.jpg
# Cropped and saved image: data/cropped_images/14_crop_38.jpg
# Cropped and saved image: data/cropped_images/14_crop_39.jpg
# Cropped and saved image: data/cropped_images/14_crop_40.jpg
# Cropped and saved image: data/cropped_images/14_crop_41.jpg
# Cropped and saved image: data/cropped_images/14_crop_42.jpg
# Cropped and saved image: data/cropped_images/14_crop_43.jpg
# Cropped and saved image: data/cropped_images/14_crop_44.jpg
# Cropped and saved image: data/cropped_images/14_crop_45.jpg
# Cropped and saved image: data/cropped_images/14_crop_46.jpg
# Cropped and saved image: data/cropped_images/14_crop_47.jpg
# Cropped and saved image: data/cropped_images/14_crop_48.jpg
# Cropped and saved image: data/cropped_images/14_crop_49.jpg
# Cropped and saved image: data/cropped_images/14_crop_50.jpg
# Cropped and saved image: data/cropped_images/14_crop_51.jpg
# Cropped and saved image: data/cropped_images/14_crop_52.jpg
# Cropped and saved image: data/cropped_images/14_crop_53.jpg
# Cropped and saved image: data/cropped_images/14_crop_54.jpg
# Cropped and saved image: data/cropped_images/14_crop_55.jpg
# Cropped and saved image: data/cropped_images/14_crop_56.jpg
# Cropped and saved image: data/cropped_images/14_crop_57.jpg
# Cropped and saved image: data/cropped_images/14_crop_58.jpg
# Cropped and saved image: data/cropped_images/14_crop_59.jpg
# Cropped and saved image: data/cropped_images/14_crop_60.jpg
# Cropped and saved image: data/cropped_images/14_crop_61.jpg
# Cropped and saved image: data/cropped_images/14_crop_62.jpg
# Cropped and saved image: data/cropped_images/14_crop_63.jpg
# Cropped and saved image: data/cropped_images/14_crop_64.jpg
# Cropped and saved image: data/cropped_images/14_crop_65.jpg
# Cropped and saved image: data/cropped_images/14_crop_66.jpg
# Cropped and saved image: data/cropped_images/14_crop_67.jpg
# Cropped and saved image: data/cropped_images/14_crop_68.jpg
# Cropped and saved image: data/cropped_images/14_crop_69.jpg
# Cropped and saved image: data/cropped_images/14_crop_70.jpg
# Cropped and saved image: data/cropped_images/14_crop_71.jpg
# Cropped and saved image: data/cropped_images/14_crop_72.jpg
# Cropped and saved image: data/cropped_images/14_crop_73.jpg
# Cropped and saved image: data/cropped_images/14_crop_74.jpg
# Cropped and saved image: data/cropped_images/14_crop_75.jpg
# Cropped and saved image: data/cropped_images/14_crop_76.jpg
# Cropped and saved image: data/cropped_images/14_crop_77.jpg
# Cropped and saved image: data/cropped_images/14_crop_78.jpg
# Cropped and saved image: data/cropped_images/14_crop_79.jpg
# Cropped and saved image: data/cropped_images/14_crop_80.jpg
# Cropped and saved image: data/cropped_images/14_crop_81.jpg
# Cropped and saved image: data/cropped_images/14_crop_82.jpg
# Cropped and saved image: data/cropped_images/14_crop_83.jpg
# Cropped and saved image: data/cropped_images/14_crop_84.jpg
# Cropped and saved image: data/cropped_images/14_crop_85.jpg
# Cropped and saved image: data/cropped_images/14_crop_86.jpg
# Cropped and saved image: data/cropped_images/14_crop_87.jpg
# Cropped and saved image: data/cropped_images/14_crop_88.jpg
# Total crops for 14.JPG: 88
# Cropped and saved image: data/cropped_images/01_crop_1.jpg
# Cropped and saved image: data/cropped_images/01_crop_2.jpg
# Cropped and saved image: data/cropped_images/01_crop_3.jpg
# Cropped and saved image: data/cropped_images/01_crop_4.jpg
# Cropped and saved image: data/cropped_images/01_crop_5.jpg
# Cropped and saved image: data/cropped_images/01_crop_6.jpg
# Cropped and saved image: data/cropped_images/01_crop_7.jpg
# Cropped and saved image: data/cropped_images/01_crop_8.jpg
# Cropped and saved image: data/cropped_images/01_crop_9.jpg
# Cropped and saved image: data/cropped_images/01_crop_10.jpg
# Cropped and saved image: data/cropped_images/01_crop_11.jpg
# Cropped and saved image: data/cropped_images/01_crop_12.jpg
# Cropped and saved image: data/cropped_images/01_crop_13.jpg
# Cropped and saved image: data/cropped_images/01_crop_14.jpg
# Cropped and saved image: data/cropped_images/01_crop_15.jpg
# Cropped and saved image: data/cropped_images/01_crop_16.jpg
# Cropped and saved image: data/cropped_images/01_crop_17.jpg
# Cropped and saved image: data/cropped_images/01_crop_18.jpg
# Cropped and saved image: data/cropped_images/01_crop_19.jpg
# Cropped and saved image: data/cropped_images/01_crop_20.jpg
# Cropped and saved image: data/cropped_images/01_crop_21.jpg
# Cropped and saved image: data/cropped_images/01_crop_22.jpg
# Cropped and saved image: data/cropped_images/01_crop_23.jpg
# Cropped and saved image: data/cropped_images/01_crop_24.jpg
# Cropped and saved image: data/cropped_images/01_crop_25.jpg
# Cropped and saved image: data/cropped_images/01_crop_26.jpg
# Cropped and saved image: data/cropped_images/01_crop_27.jpg
# Cropped and saved image: data/cropped_images/01_crop_28.jpg
# Cropped and saved image: data/cropped_images/01_crop_29.jpg
# Cropped and saved image: data/cropped_images/01_crop_30.jpg
# Cropped and saved image: data/cropped_images/01_crop_31.jpg
# Cropped and saved image: data/cropped_images/01_crop_32.jpg
# Cropped and saved image: data/cropped_images/01_crop_33.jpg
# Cropped and saved image: data/cropped_images/01_crop_34.jpg
# Cropped and saved image: data/cropped_images/01_crop_35.jpg
# Cropped and saved image: data/cropped_images/01_crop_36.jpg
# Cropped and saved image: data/cropped_images/01_crop_37.jpg
# Cropped and saved image: data/cropped_images/01_crop_38.jpg
# Cropped and saved image: data/cropped_images/01_crop_39.jpg
# Cropped and saved image: data/cropped_images/01_crop_40.jpg
# Cropped and saved image: data/cropped_images/01_crop_41.jpg
# Cropped and saved image: data/cropped_images/01_crop_42.jpg
# Cropped and saved image: data/cropped_images/01_crop_43.jpg
# Cropped and saved image: data/cropped_images/01_crop_44.jpg
# Cropped and saved image: data/cropped_images/01_crop_45.jpg
# Cropped and saved image: data/cropped_images/01_crop_46.jpg
# Cropped and saved image: data/cropped_images/01_crop_47.jpg
# Cropped and saved image: data/cropped_images/01_crop_48.jpg
# Cropped and saved image: data/cropped_images/01_crop_49.jpg
# Cropped and saved image: data/cropped_images/01_crop_50.jpg
# Cropped and saved image: data/cropped_images/01_crop_51.jpg
# Cropped and saved image: data/cropped_images/01_crop_52.jpg
# Cropped and saved image: data/cropped_images/01_crop_53.jpg
# Cropped and saved image: data/cropped_images/01_crop_54.jpg
# Cropped and saved image: data/cropped_images/01_crop_55.jpg
# Cropped and saved image: data/cropped_images/01_crop_56.jpg
# Cropped and saved image: data/cropped_images/01_crop_57.jpg
# Cropped and saved image: data/cropped_images/01_crop_58.jpg
# Cropped and saved image: data/cropped_images/01_crop_59.jpg
# Cropped and saved image: data/cropped_images/01_crop_60.jpg
# Cropped and saved image: data/cropped_images/01_crop_61.jpg
# Cropped and saved image: data/cropped_images/01_crop_62.jpg
# Cropped and saved image: data/cropped_images/01_crop_63.jpg
# Cropped and saved image: data/cropped_images/01_crop_64.jpg
# Cropped and saved image: data/cropped_images/01_crop_65.jpg
# Cropped and saved image: data/cropped_images/01_crop_66.jpg
# Cropped and saved image: data/cropped_images/01_crop_67.jpg
# Cropped and saved image: data/cropped_images/01_crop_68.jpg
# Cropped and saved image: data/cropped_images/01_crop_69.jpg
# Cropped and saved image: data/cropped_images/01_crop_70.jpg
# Cropped and saved image: data/cropped_images/01_crop_71.jpg
# Cropped and saved image: data/cropped_images/01_crop_72.jpg
# Cropped and saved image: data/cropped_images/01_crop_73.jpg
# Cropped and saved image: data/cropped_images/01_crop_74.jpg
# Cropped and saved image: data/cropped_images/01_crop_75.jpg
# Cropped and saved image: data/cropped_images/01_crop_76.jpg
# Cropped and saved image: data/cropped_images/01_crop_77.jpg
# Cropped and saved image: data/cropped_images/01_crop_78.jpg
# Cropped and saved image: data/cropped_images/01_crop_79.jpg
# Cropped and saved image: data/cropped_images/01_crop_80.jpg
# Cropped and saved image: data/cropped_images/01_crop_81.jpg
# Cropped and saved image: data/cropped_images/01_crop_82.jpg
# Cropped and saved image: data/cropped_images/01_crop_83.jpg
# Cropped and saved image: data/cropped_images/01_crop_84.jpg
# Cropped and saved image: data/cropped_images/01_crop_85.jpg
# Cropped and saved image: data/cropped_images/01_crop_86.jpg
# Cropped and saved image: data/cropped_images/01_crop_87.jpg
# Cropped and saved image: data/cropped_images/01_crop_88.jpg
# Total crops for 01.JPG: 88
# Cropped and saved image: data/cropped_images/23_crop_1.jpg
# Cropped and saved image: data/cropped_images/23_crop_2.jpg
# Cropped and saved image: data/cropped_images/23_crop_3.jpg
# Cropped and saved image: data/cropped_images/23_crop_4.jpg
# Cropped and saved image: data/cropped_images/23_crop_5.jpg
# Cropped and saved image: data/cropped_images/23_crop_6.jpg
# Cropped and saved image: data/cropped_images/23_crop_7.jpg
# Cropped and saved image: data/cropped_images/23_crop_8.jpg
# Cropped and saved image: data/cropped_images/23_crop_9.jpg
# Cropped and saved image: data/cropped_images/23_crop_10.jpg
# Cropped and saved image: data/cropped_images/23_crop_11.jpg
# Cropped and saved image: data/cropped_images/23_crop_12.jpg
# Cropped and saved image: data/cropped_images/23_crop_13.jpg
# Cropped and saved image: data/cropped_images/23_crop_14.jpg
# Cropped and saved image: data/cropped_images/23_crop_15.jpg
# Cropped and saved image: data/cropped_images/23_crop_16.jpg
# Cropped and saved image: data/cropped_images/23_crop_17.jpg
# Cropped and saved image: data/cropped_images/23_crop_18.jpg
# Cropped and saved image: data/cropped_images/23_crop_19.jpg
# Cropped and saved image: data/cropped_images/23_crop_20.jpg
# Cropped and saved image: data/cropped_images/23_crop_21.jpg
# Cropped and saved image: data/cropped_images/23_crop_22.jpg
# Cropped and saved image: data/cropped_images/23_crop_23.jpg
# Cropped and saved image: data/cropped_images/23_crop_24.jpg
# Cropped and saved image: data/cropped_images/23_crop_25.jpg
# Cropped and saved image: data/cropped_images/23_crop_26.jpg
# Cropped and saved image: data/cropped_images/23_crop_27.jpg
# Cropped and saved image: data/cropped_images/23_crop_28.jpg
# Cropped and saved image: data/cropped_images/23_crop_29.jpg
# Cropped and saved image: data/cropped_images/23_crop_30.jpg
# Cropped and saved image: data/cropped_images/23_crop_31.jpg
# Cropped and saved image: data/cropped_images/23_crop_32.jpg
# Cropped and saved image: data/cropped_images/23_crop_33.jpg
# Cropped and saved image: data/cropped_images/23_crop_34.jpg
# Cropped and saved image: data/cropped_images/23_crop_35.jpg
# Cropped and saved image: data/cropped_images/23_crop_36.jpg
# Cropped and saved image: data/cropped_images/23_crop_37.jpg
# Cropped and saved image: data/cropped_images/23_crop_38.jpg
# Cropped and saved image: data/cropped_images/23_crop_39.jpg
# Cropped and saved image: data/cropped_images/23_crop_40.jpg
# Cropped and saved image: data/cropped_images/23_crop_41.jpg
# Cropped and saved image: data/cropped_images/23_crop_42.jpg
# Cropped and saved image: data/cropped_images/23_crop_43.jpg
# Cropped and saved image: data/cropped_images/23_crop_44.jpg
# Cropped and saved image: data/cropped_images/23_crop_45.jpg
# Cropped and saved image: data/cropped_images/23_crop_46.jpg
# Cropped and saved image: data/cropped_images/23_crop_47.jpg
# Cropped and saved image: data/cropped_images/23_crop_48.jpg
# Cropped and saved image: data/cropped_images/23_crop_49.jpg
# Cropped and saved image: data/cropped_images/23_crop_50.jpg
# Cropped and saved image: data/cropped_images/23_crop_51.jpg
# Cropped and saved image: data/cropped_images/23_crop_52.jpg
# Cropped and saved image: data/cropped_images/23_crop_53.jpg
# Cropped and saved image: data/cropped_images/23_crop_54.jpg
# Cropped and saved image: data/cropped_images/23_crop_55.jpg
# Cropped and saved image: data/cropped_images/23_crop_56.jpg
# Cropped and saved image: data/cropped_images/23_crop_57.jpg
# Cropped and saved image: data/cropped_images/23_crop_58.jpg
# Cropped and saved image: data/cropped_images/23_crop_59.jpg
# Cropped and saved image: data/cropped_images/23_crop_60.jpg
# Cropped and saved image: data/cropped_images/23_crop_61.jpg
# Cropped and saved image: data/cropped_images/23_crop_62.jpg
# Cropped and saved image: data/cropped_images/23_crop_63.jpg
# Cropped and saved image: data/cropped_images/23_crop_64.jpg
# Cropped and saved image: data/cropped_images/23_crop_65.jpg
# Cropped and saved image: data/cropped_images/23_crop_66.jpg
# Cropped and saved image: data/cropped_images/23_crop_67.jpg
# Cropped and saved image: data/cropped_images/23_crop_68.jpg
# Cropped and saved image: data/cropped_images/23_crop_69.jpg
# Cropped and saved image: data/cropped_images/23_crop_70.jpg
# Cropped and saved image: data/cropped_images/23_crop_71.jpg
# Cropped and saved image: data/cropped_images/23_crop_72.jpg
# Cropped and saved image: data/cropped_images/23_crop_73.jpg
# Cropped and saved image: data/cropped_images/23_crop_74.jpg
# Cropped and saved image: data/cropped_images/23_crop_75.jpg
# Cropped and saved image: data/cropped_images/23_crop_76.jpg
# Cropped and saved image: data/cropped_images/23_crop_77.jpg
# Cropped and saved image: data/cropped_images/23_crop_78.jpg
# Cropped and saved image: data/cropped_images/23_crop_79.jpg
# Cropped and saved image: data/cropped_images/23_crop_80.jpg
# Cropped and saved image: data/cropped_images/23_crop_81.jpg
# Cropped and saved image: data/cropped_images/23_crop_82.jpg
# Cropped and saved image: data/cropped_images/23_crop_83.jpg
# Cropped and saved image: data/cropped_images/23_crop_84.jpg
# Cropped and saved image: data/cropped_images/23_crop_85.jpg
# Cropped and saved image: data/cropped_images/23_crop_86.jpg
# Cropped and saved image: data/cropped_images/23_crop_87.jpg
# Cropped and saved image: data/cropped_images/23_crop_88.jpg
# Total crops for 23.JPG: 88
